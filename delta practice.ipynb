# %%
data = [
    (1, "Alice", 28, "Finance"),
    (2, "Bob", 35, "IT"),
    (3, "Cathy", 23, "Marketing"),
    (4, "David", 40, "HR")
]
schema=['id','name','age','department']
df=spark.createDataFrame(data,schema)
df.show()
df.filter(df.name=='Alice')
